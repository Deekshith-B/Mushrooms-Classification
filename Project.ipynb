# %% [markdown]
# # SUMMARY OF DATASET.

# %% [markdown]
# * The name of our dataset is mushrooms.csv.
# * The dataset consists information about mushrooms different features.
# * A mushroom or toadstool is the fleshy, spore-bearing fruiting body of a fungus, typically produced above ground, on soil, or on its food source.
# * The scientific classification is Kingdom:Fungi and Phylum:Basidiomycota.

# %% [markdown]
# #### Lets proceed and see what information our dataset interprets.

# %% [markdown]
# ## IMPORTING PACKAGES AND READING DATSET.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # OVERVIEW OF DATASET.

# %% [markdown]
# ### INTERPRETING THE ENTRIES AND INFORMATION OF DATSET.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# * From above interpreted data we can observe that there are total 8124 rows and 23 columns.
# * Also we can see that all datapoints are in object type.

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %% [markdown]
# Conclusion from above interpreted data
# * The count in every column is the same as there are no missing values.
# * Also every column has unique values ranging from 2-12 unique values in each column.
# * Further are frequency of most repeating value in each columns.

# %% [markdown]
# ## DATA CLEANING

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# * As we can observe the data consist no nan values.

# %% [markdown]
# ## CLEANING THE IMPURE VALUES IN COLUMNS.

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# * No impure values.
# * classes: edible=e, poisonous=p

# %%
df['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %% [markdown]
# * No impure values.
# * cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s

# %%
df['cap-surface'].unique()
# Out:
# array(['s', 'y', 'f', 'g'], dtype=object)

# %% [markdown]
# * No impure values.
# * cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s

# %%
df['cap-color'].unique()
# Out:
# array(['n', 'y', 'w', 'g', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object)

# %% [markdown]
# * No impure values.
# * cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y

# %%
df['bruises'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %% [markdown]
# * No impure values.
# * bruises: bruises=t,no=f

# %%
df['odor'].unique()
# Out:
# array(['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object)

# %% [markdown]
# * No impure values.
# * odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s

# %%
df['gill-attachment'].unique()
# Out:
# array(['f', 'a'], dtype=object)

# %% [markdown]
# * No impure values.
# * gill-attachment: attached=a,free=f

# %%
df['gill-spacing'].unique()
# Out:
# array(['c', 'w'], dtype=object)

# %% [markdown]
# * No impure values.
# * gill-spacing: close=c,crowded=w

# %%
df['gill-size'].unique()
# Out:
# array(['n', 'b'], dtype=object)

# %% [markdown]
# * No impure values.
# * gill-size: broad=b,narrow=n

# %%
df['gill-color'].unique()
# Out:
# array(['k', 'n', 'g', 'p', 'w', 'h', 'u', 'e', 'b', 'r', 'y', 'o'],
#       dtype=object)

# %% [markdown]
# * No impure values.
# * gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y

# %%
df['stalk-shape'].unique()
# Out:
# array(['e', 't'], dtype=object)

# %% [markdown]
# * No impure values.
# * stalk-shape: enlarging=e,tapering=t

# %%
df["stalk-root"].replace({"?":np.nan}, inplace=True)
df['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', nan], dtype=object)

# %% [markdown]
# * Impure values replaced with nan value.
# * stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?

# %%
df['stalk-surface-above-ring'].unique()
# Out:
# array(['s', 'f', 'k', 'y'], dtype=object)

# %% [markdown]
# * No impure values.
# * stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s

# %%
df['stalk-surface-below-ring'].unique()
# Out:
# array(['s', 'f', 'y', 'k'], dtype=object)

# %% [markdown]
# * No impure values.
# * stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s

# %%
df['stalk-color-above-ring'].unique()
# Out:
# array(['w', 'g', 'p', 'n', 'b', 'e', 'o', 'c', 'y'], dtype=object)

# %% [markdown]
# * No impure values.
# * stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y

# %%
df['stalk-color-below-ring'].unique()
# Out:
# array(['w', 'p', 'g', 'b', 'n', 'e', 'y', 'o', 'c'], dtype=object)

# %% [markdown]
# * No impure values.
# * stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y

# %%
df['veil-type'].unique()
# Out:
# array(['p'], dtype=object)

# %% [markdown]
# * No impure values.
# * veil-type: partial=p

# %%
df['veil-color'].unique()
# Out:
# array(['w', 'n', 'o', 'y'], dtype=object)

# %% [markdown]
# * No impure values.
# * veil-color: brown=n,orange=o,white=w,yellow=y

# %%
df['ring-number'].unique()
# Out:
# array(['o', 't', 'n'], dtype=object)

# %% [markdown]
# * No impure values.
# * ring-number: none=n,one=o,two=t

# %%
df['ring-type'].unique()
# Out:
# array(['p', 'e', 'l', 'f', 'n'], dtype=object)

# %% [markdown]
# * No impure values.
# * ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s

# %%
df['spore-print-color'].unique()
# Out:
# array(['k', 'n', 'u', 'h', 'w', 'r', 'o', 'y', 'b'], dtype=object)

# %% [markdown]
# * No impure values.
# * spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y

# %%
df['population'].unique()
# Out:
# array(['s', 'n', 'a', 'v', 'y', 'c'], dtype=object)

# %% [markdown]
# * No impure values.
# * population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y

# %%
df['habitat'].unique()
# Out:
# array(['u', 'g', 'm', 'd', 'p', 'w', 'l'], dtype=object)

# %% [markdown]
# * No impure values.
# * habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %% [markdown]
# ## FILLING THE NAN VALUES.

# %% [markdown]
# #### FILLING THE CATEGORICAL COLUMNS.

# %%
df["stalk-root"] = df["stalk-root"].fillna(method="ffill")

# %%
df['stalk-root'].value_counts()
# Out:
# b    5207
# c    1605
# e    1120
# r     192
# Name: stalk-root, dtype: int64

# %% [markdown]
# ### Mapping the real names to data points

# %%
capshape={"b":"bell","c":"conical","x":"convex","f":"flat","k":"knobbed","s":"sunken"}
df["cap-shape"]=df["cap-shape"].replace(capshape)

capsurface={"f": "fibrous", "g": "grooves","y":"scaly","s": "smooth"}
df["cap-surface"]=df["cap-surface"].replace(capsurface)

capcolor={"n":"brown","b":"buff","c":"cinnamon","g":"gray","r":"green","p":"pink","u":"purple","e":"red","w":"white","y":"yellow"}
df["cap-color"]=df["cap-color"].replace(capcolor)

odor={"a":"almond","l":"anise","c":"creosote","y":"fishy","f":"foul","m":"musty","n":"none","p":"pungent","s":"spicy"}
df["odor"]=df["odor"].replace(odor)

gillattachment={"a":"attached","f":"free"}
df["gill-attachment"]=df["gill-attachment"].replace(gillattachment)

gillspacing={"c":"close","w":"crowded"}
df["gill-spacing"]=df["gill-spacing"].replace(gillspacing)

gillsize={"b":"broad","n":"narrow"}
df["gill-size"]=df["gill-size"].replace(gillsize)

gillcolor={"k":"black","b":"buff","n":"brown","h":"chocolate","g":"gray","r":"green","o":"orange","p":"pink","u":"purple","e":"red","w":"white","y":"yellow"}
df["gill-color"]=df["gill-color"].replace(gillcolor)

stalkshape={"t":"tapering","e":"enlarging"}
df["stalk-shape"]=df["stalk-shape"].replace(stalkshape)

stalkroot={"b":"bulbous","c":"club","e":"equal","z":"rhizomorphs","r":"rooted","?":"missing"}
df["stalk-root"]=df["stalk-root"].replace(stalkroot)

stalksurface={"s":"smooth","k":"silky","f":"fibrous","y":"scaly"}
df["stalk-surface-above-ring"]=df["stalk-surface-above-ring"].replace(stalksurface)
df["stalk-surface-below-ring"]=df["stalk-surface-below-ring"].replace(stalksurface)

stalkcolor ={"n":"brown","b":"buff","c":"cinnamon","g":"gray","p":"pink","e":"red","w":"white","y":"yellow","o":"orange"}
df["stalk-color-above-ring"]=df["stalk-color-above-ring"].replace(stalkcolor)
df["stalk-color-below-ring"]=df["stalk-color-below-ring"].replace(stalkcolor)

veiltype={"p":"partial","u":"universal"} 
df["veil-type"]=df["veil-type"].replace(veiltype)

veilcolor={"n":"brown","o":"orange","w":"white","y":"yellow"} 
df["veil-color"]=df["veil-color"].replace(veilcolor)

ringnumber= {"n":"none","o":"one","t":"two"}
df["ring-number"]=df["ring-number"].replace(ringnumber)

ringtype={"c":"cobwebby","e":"evanescent","f":"flaring","l":"large","n":"none","p":"pendant","s":"sheathing","z":"zone"}
df["ring-type"]=df["ring-type"].replace(ringtype)

sporeprintcolor= {"k":"black","n":"brown","b":"buff","h":"chocolate","r":"green","o":"orange","u":"purple","w":"white","y":"yellow"}
df["spore-print-color"]=df["spore-print-color"].replace(sporeprintcolor)

population={"a":"abundant","c":"clustered","n":"numerous","s":"scattered","v":"several","y":"solitary"}
df["population"]=df["population"].replace(population)

habitat={"g":"grasses","l":"leaves","m":"meadows","p":"paths","u":"urban","w":"waste","d":"woods"}
df["habitat"]=df["habitat"].replace(habitat)

bruises={'t':'bruises','f':'no'}
df["bruises"]=df["bruises"].replace(bruises)

# %%
df
# Out:
#      class cap-shape cap-surface cap-color  bruises     odor gill-attachment  \
# 0        p    convex      smooth     brown  bruises  pungent            free
# 1        e    convex      smooth    yellow  bruises   almond            free
# 2        e      bell      smooth     white  bruises    anise            free
# 3        p    convex       scaly     white  bruises  pungent            free
# 4        e    convex      smooth      gray       no     none            free
# ...    ...       ...         ...       ...      ...      ...             ...
# 8119     e   knobbed      smooth     brown       no     none        attached
# 8120     e    convex      smooth     brown       no     none        attached
# 8121     e      flat      smooth     brown       no     none        attached
# 8122     p   knobbed       scaly     brown       no    fishy            free
# 8123     e    convex      smooth     brown       no     none        attached
#
# ...

# %% [markdown]
# ##### We have done with the data cleaning part , now lets move forward to EDA and Pre-Processing.

# %% [markdown]
# # EDA & PRE-PROCESSING

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color  bruises     odor gill-attachment  \
# 0     p    convex      smooth     brown  bruises  pungent            free
# 1     e    convex      smooth    yellow  bruises   almond            free
# 2     e      bell      smooth     white  bruises    anise            free
# 3     p    convex       scaly     white  bruises  pungent            free
# 4     e    convex      smooth      gray       no     none            free
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0        close    narrow      black  ...                   smooth
# 1        close     broad      black  ...                   smooth
# 2        close     broad      brown  ...                   smooth
# 3        close    narrow      brown  ...                   smooth
# 4      crowded     broad      black  ...                   smooth
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
sns.countplot(df['class'],palette=['#41ab5d','#addd8e'])
plt.title('Distribution of Mushrooms by their classes')
plt.grid(True)

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
plt.figure(figsize=(6,6))
df["class"].value_counts().plot(kind="pie",autopct='%0.2f%%')
plt.title('Distribution of Mushrooms by their classes')
# Out:
# Text(0.5, 1.0, 'Distribution of Mushrooms by their classes')

# %% [markdown]
# * The above graph shows us that more than 4208(51.08%) mushrooms are edible and 3916(48.20%) mushrooms are poisonous

# %%
sns.countplot(data=df,x=df['cap-shape'],hue=df['class'],palette=['#d95f02','#E29539'])
plt.title('Distribution of Mushrooms by their classes and cap-shape')
plt.grid(True)

# %% [markdown]
# * According to this graph, the Convex Cap Shape is the most frequent. The Edible and Poisonous class mushrooms are pretty close to each other for the Convex and the Flat type. In contrast, for the following types which are Kobbed and Bell, the class types are pretty imbalanced distributed. The Sunken and the Conical types are completely edible.

# %%
sns.countplot(data=df,x=df['cap-surface'],hue=df['class'])
plt.title('Distribution of Mushrooms by their classes and cap-shape')
plt.grid(True)

# %% [markdown]
# * As seen from the figure, the Scaly and Smooth types are high probability poisonous. In contrast, the Fibrous type is mostly edible.

# %%
sns.countplot(data=df,x=df['cap-color'],hue=df['class'],palette=['#DFAE74','#DCCEBE'])
plt.title('Distribution of Mushrooms by their classes and cap-color')
plt.grid(True)

# %% [markdown]
# * According to this graph, the Edible and Poisonous class mushrooms are pretty close to each other for Brown, Gray, and Red cap colors. The White cap-colored mushrooms are highly edible. Purple and Green cape-colored mushrooms have no poisonous class.

# %%
sns.countplot(data=df,x=df['bruises'],hue=df['class'],palette=["#fc9272","#fee0d2"])
plt.title('Distribution of Mushrooms by their classes and bruises')
plt.grid(True)

# %% [markdown]
# * As you can see from the graph above, Mushrooms without Bruises are high frequently poisonous. In contrast, the Mushrooms with the Bruises are highly edible.

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df,x=df['odor'],hue=df['class'],palette=['#999999','#de78ae'])
plt.title('Distribution of Mushrooms by their classes and odor')
plt.grid(True)

# %% [markdown]
# * According to the graph above, mushrooms with no odor are highly safe for humans. But the mushrooms with the Foul, Fishy, and Spicy odor are high frequently poisonous. The mushrooms with the Anise and Almond odor have no poisonous class.

# %%
sns.countplot(data=df,x=df['gill-attachment'],hue=df['class'],palette= ["#7fcdbb","#edf8b1"])
plt.title('Distribution of Mushrooms by their classes and gill-attachment')
plt.grid(True)

# %% [markdown]
# * The dataset has high frequently Free type gill attachments. According to this graph, the Free type gill attachments are approximately equally distributed. In contrast, the Attached type gill attachments are most frequently edible.

# %%
sns.countplot(data=df,x=df['gill-spacing'],hue=df['class'],palette= ['#7570b3','#fdb462'])
plt.title('Distribution of Mushrooms by their classes and gill-spacing')
plt.grid(True)

# %% [markdown]
# * According to this figure, the Crowded type gill spacing is high frequently edible. In contrast, we cannot say the same thing for the Close-type gill spacing mushrooms. Their class distribution by gill spacing is pretty close to each other.

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=df,x=df['gill-color'],hue=df['class'],palette= ['#00ccff','#3d3f42'])
plt.title('Distribution of Mushrooms by their classes and gill-color')
plt.grid(True)

# %% [markdown]
# * As seen from the figure above, the Buff-colored gills are highly poisonous. In contrast, the White, Brown, Purple, Black, and Red gill colors are high frequently edible.

# %%
sns.countplot(data=df,x=df['stalk-shape'],hue=df['class'],palette= ['#1d91c0','#edf8b1'])
plt.title('Distribution of Mushrooms by their classes and stalk-shape')
plt.grid(True)

# %% [markdown]
# * As seen in above graph stalk shape like tapering are more edible compare to enlarging shape.

# %%
sns.countplot(data=df,x=df['stalk-root'],hue=df['class'],palette= ['#a8ddb5','#ccebc5'])
plt.title('Distribution of Mushrooms by their classes and stalk-root')
plt.grid(True)

# %% [markdown]
# * As seen from the figure, most data points are Bulbous-type stalk root. The Equal, Club, and Rooted type stalk roots are highly edible but the Bulbous type stalk root is highly poisonous.

# %%
sns.countplot(data=df,x=df['stalk-surface-above-ring'],hue=df['class'],palette= ['#4eb3d3','#D55E00'])
plt.title('Distribution of Mushrooms by their classes and stalk-surface-above-ring')
plt.grid(True)

# %%
sns.countplot(data=df,x=df['stalk-surface-below-ring'],hue=df['class'],palette= ['#bf00bf','#000000'])
plt.title('Distribution of Mushrooms by their classes and stalk-surface-below-ring')
plt.grid(True)

# %% [markdown]
# * As seen in above both plot smooth surface stalk mushrooms are edible whereas silky textures mushroom are more poisonous.
# * Also scaly surface mushroom have no edible and poisonous mushrooms.

# %%
sns.countplot(data=df,x=df['veil-type'],hue=df['class'],palette= ['#4eb3d3','#6a3d9a'])
plt.title('Distribution of Mushrooms by their classes and veil-type')
plt.grid(True)

# %% [markdown]
# * As you can see, most of them are edible but the number of the poisonous class mushrooms are pretty close to the edible class of mushrooms.

# %%
sns.countplot(data=df,x=df['veil-color'],hue=df['class'],palette= ['#ffff33','#4daf4a'])
plt.title('Distribution of Mushrooms by their classes and veil-color')
plt.grid(True)

# %% [markdown]
# * According to our dataset, most of the mushrooms have White colors. The class distribution of the White-colored Veils is approximately equal. The Brown, Orange, and Yellow Veil-colored mushrooms have no poisonous class.

# %%
plt.figure(figsize=(7,5))
df['ring-number'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <AxesSubplot:ylabel='ring-number'>

# %%
df['ring-number'].value_counts()
# Out:
# one     7488
# two      600
# none      36
# Name: ring-number, dtype: int64

# %% [markdown]
# * From above pie chart we conclude that most of the mushroom have one ring(7488) and second largest is two rings on stalk whereas 36 mushrooms have no ring on them.

# %%
sns.countplot(data=df,x=df['ring-number'],hue=df['class'],palette= ['#8C0900','#00D7FF'])
plt.title('Distribution of Mushrooms by their classes and ring-number')
plt.grid(True)

# %% [markdown]
# * Further we can also say that mushrooms having single ring are equal in edible and poisonous category,mushrooms with no ring are not edible.

# %%
df['ring-type'].value_counts()
# Out:
# pendant       3968
# evanescent    2776
# large         1296
# flaring         48
# none            36
# Name: ring-type, dtype: int64

# %%
plt.figure(figsize=(8,18))
df['ring-type'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <AxesSubplot:ylabel='ring-type'>

# %% [markdown]
# * According to chart we can observe that mushrooms have mostly ring pendant,evanescent and large also there are some mushroooms which has no ring shape on them.

# %%
sns.countplot(data=df,x=df['ring-type'],hue=df['class'],palette= ['#6ACC65','#3498db'])
plt.title('Distribution of Mushrooms by their classes and ring-type')
plt.grid(True)

# %% [markdown]
# * As seen from the graph, the mushrooms with the Pendant type are high frequently edible. In contrast, the mushrooms with the Large type have only the poisonous class.

# %%
sns.countplot(data=df,x=df['spore-print-color'],hue=df['class'],palette= ['#80b1d3','#fdc086'])
plt.title('Distribution of Mushrooms by their classes and spore-print-color')
plt.grid(True)

# %% [markdown]
# * As seen from the figure, the White and Chocolate spore print colored mushrooms are high frequently poisonous. In contrast, the mushrooms with the Brown and Black spore print colors are high frequently edible.

# %%
df['habitat'].value_counts()
# Out:
# woods      3148
# grasses    2148
# paths      1144
# leaves      832
# urban       368
# meadows     292
# waste       192
# Name: habitat, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(df['habitat'].value_counts(),labels=df['habitat'].value_counts().keys(), autopct='%1.1f%%', shadow = True)
plt.title('Habitat')
plt.show()

# %%
sns.countplot(data=df,x=df['habitat'],hue=df['class'],palette= ['#80b1d3','#fdc086'])
plt.title('Distribution of Mushrooms by their classes and habitat')
plt.grid(True)

# %% [markdown]
# * The graph tells us that in woods is most perfect place for mushrooms to grow as both edible and poisonous are found large numbers.
# * Whereas urban has lowest no of edible mushrooms and waste has lowest no of poisonous mushrooms.

# %%
df['population'].value_counts()
# Out:
# several      4040
# solitary     1712
# scattered    1248
# numerous      400
# abundant      384
# clustered     340
# Name: population, dtype: int64

# %%
sns.countplot(data=df,x=df['population'],hue=df['class'],palette= ['#4C72B0','#B0E0E6'])
plt.title('Distribution of Mushrooms by their classes and population')
plt.grid(True)

# %% [markdown]
# *  According to the graph above, the mushrooms populated as Several types are highly poisonous as compare to the mushrooms with Numerous, Abundant, and Clustered populations are pretty edible.

# %%
plt.figure(figsize=(10,10))
sns.countplot(data=df,x=df['habitat'],hue=df['population'],palette= ['#34495e','#3498db','#55A868','#e31a1c','#b15928','#e74c3c'])
plt.title('Distribution of Mushrooms by their habitat and population')
plt.grid(True)

# %% [markdown]
# * Urban habitat has several,clustered and scattered types of population.
# * Grasses is the only habitat which has every type of population.
# * Woods on the other hand has several population in large no compared to others.
# * Whereas waste has only one type of population which is clustered and leaves clustered and several populations.

# %% [markdown]
# # Converting categorical data into numerical data

# %% [markdown]
# #### ENCODING THE DATA USING LABEL ENCODER.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in df:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          2            3          0        0     7
# 1         0          2            3          9        0     0
# 2         0          0            3          8        0     1
# 3         1          2            2          8        0     7
# 4         0          2            3          3        1     6
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          4            3          0        1     6
# 8120      0          2            3          0        1     6
# 8121      0          3            3          0        1     6
# 8122      1          4            2          0        1     3
# 8123      0          2            3          0        1     6
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           0  ...
# 1                   1             0          0           0  ...
# ...

# %% [markdown]
# ## PAIRPLOT

# %%
sns.pairplot(df)

# %%
sns.pairplot(data=df,hue="class")

# %% [markdown]
# # MODEL CREATION.

# %% [markdown]
# #### SPLITTING THE DATA IN DEPENDENT & INDEPENDENT SET.

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            3          0        0     7                1
# 1             2            3          9        0     0                1
# 2             0            3          8        0     1                1
# 3             2            2          8        0     7                1
# 4             2            3          3        1     6                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          4            3          0        1     6                0
# 8120          2            3          0        1     6                0
# 8121          3            3          0        1     6                0
# 8122          4            2          0        1     3                1
# 8123          2            3          0        1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.3,random_state = 1)

# %% [markdown]
# #### IMPORTING THE MODELS AND PACKAGES.

# %%
from sklearn.model_selection import train_test_split,cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    ac=accuracy_score(ytest,ypred)
    cm=confusion_matrix(ytest,ypred)
    cr=classification_report(ytest,ypred)
    
    print('Accuracy Score       :{}'.format(ac))
    print('Confusion Matrix     :\n{}'.format(cm))
    print('Classification report:\n{}'.format(cr))
    return model

# %%
knn=KNeighborsClassifier()
knn=mymodel(knn)
# Out:
# Accuracy Score       :0.9987694831829368
# Confusion Matrix     :
# [[1236    0]
#  [   3 1199]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1236
#            1       1.00      1.00      1.00      1202
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
lr=LogisticRegression()
lr=mymodel(lr)
# Out:
# Accuracy Score       :0.9552912223133716
# Confusion Matrix     :
# [[1187   49]
#  [  60 1142]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      1236
#            1       0.96      0.95      0.95      1202
#
#     accuracy                           0.96      2438
#    macro avg       0.96      0.96      0.96      2438
# weighted avg       0.96      0.96      0.96      2438

# %%
svm=SVC()
svm=mymodel(svm)
# Out:
# Accuracy Score       :0.9938474159146842
# Confusion Matrix     :
# [[1236    0]
#  [  15 1187]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1236
#            1       1.00      0.99      0.99      1202
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %% [markdown]
# #### From above interpreted reports we can observe that SVM both and knn is providing good results, and Logistic regression is giving is also giving a good score.

# %% [markdown]
# ## CROSS VALIDATION.

# %%
cvs = cross_val_score(knn,x,y,cv=10,scoring="accuracy")
print('Cross Val Score:{}'.format(cvs.mean()))
# Out:
# Cross Val Score:0.9432600779209762

# %%
cvs = cross_val_score(lr,x,y,cv=10,scoring="accuracy")
print('Cross Val Score:{}'.format(cvs.mean()))
# Out:
# Cross Val Score:0.9432600779209762

# %%
cvs = cross_val_score(svm,x,y,cv=10,scoring="accuracy")
print('Cross Val Score:{}'.format(cvs.mean()))
# Out:
# Cross Val Score:0.931440901847442

# %% [markdown]
# As seen in above cross val score for all alogorithm the score is mostly above 92%.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### Class:

# %% [markdown]
# * Out of total 8124 mushrooms 51.80% are edible and 48.20% are poisonous.
# * Numerically 4208 mushrooms are edible and 3916 are poisonous.

# %% [markdown]
# ## Cap:

# %% [markdown]
# * The Convex Cap Shape is the most frequent. The Edible and Poisonous class mushrooms are pretty close to each other for the Convex and the Flat type. In contrast, for the following types which are Kobbed and Bell, the class types are pretty imbalanced distributed. The Sunken and the Conical types are completely edible.
#
# * The Scaly and Smooth types are high probability poisonous. In contrast, the Fibrous type is mostly edible.
#
# * The Edible and Poisonous class mushrooms are pretty close to each other for Brown, Gray, and Red cap colors. The White cap-colored mushrooms are highly edible. Purple and Green cape-colored mushrooms have no poisonous class.

# %% [markdown]
# ## Gill:

# %% [markdown]
# * The Free type gill attachments are approximately equally distributed. In contrast, the Attached type gill attachments are most frequently edible.
#
# * The Crowded type gill spacing is high frequently edible. In contrast, we cannot say the same thing for the Close-type gill spacing mushrooms. Their class distribution by gill spacing is pretty close to each other.
#
# * the Buff-colored gills are highly poisonous. In contrast, the White, Brown, Purple, Black, and Red gill colors are high frequently edible.

# %% [markdown]
# ## Stalk:

# %% [markdown]
# * Stalk shape like tapering are more edible compare to enlarging shape.
# * Most data points are Bulbous-type stalk root. The Equal, Club, and Rooted type stalk roots are highly edible but the Bulbous type stalk root is highly poisonous.
# * Smooth surface stalk mushrooms are edible whereas silky textures mushroom are more poisonous.
# * Also scaly surface mushroom have no edible and poisonous mushrooms.

# %% [markdown]
# ## Veil:

# %% [markdown]
# * Most of them are edible but the number of the poisonous class mushrooms are pretty close to the edible class of mushrooms.
# * Also most of the mushrooms have White colors. The class distribution of the White-colored Veils is approximately equal. The Brown, Orange, and Yellow Veil-colored mushrooms have no poisonous class.

# %% [markdown]
# ## Ring:

# %% [markdown]
# * Mushroom have one ring(7488) and second largest is two rings on stalk whereas 36 mushrooms have no ring on them.
# * Mostly ring pendant,evanescent and large also there are some mushroooms which has no ring shape on them.

# %% [markdown]
# ## Spore:

# %% [markdown]
# * The White and Chocolate spore print colored mushrooms are high frequently poisonous. In contrast, the mushrooms with the Brown and Black spore print colors are high frequently edible.

# %% [markdown]
# ## Population:

# %% [markdown]
# * The mushrooms populated as Several types are highly poisonous as compare to the mushrooms with Numerous, Abundant, and Clustered populations are pretty edible.

# %% [markdown]
# ## Habitat:

# %% [markdown]
# * The dataset tells us that in woods is most perfect place for mushrooms to grow as both edible and poisonous are found large numbers.
# * Whereas urban has lowest no of edible mushrooms and waste has lowest no of poisonous mushrooms.

# %% [markdown]
# ## Results:

# %% [markdown]
# Considering all the accuracies provided by different models the highest accuracy which we achieved is of 99% by the KNN and SVC model.
